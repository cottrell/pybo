# %%
import pybo.demos

# %%
# %%time
# %matplotlib inline
pybo.demos.beginner.main()
# Out:
# CPU times: user 3min 48s, sys: 9.21 s, total: 3min 57s
# Wall time: 3min 52s

# %%
# %%time
# %matplotlib inline
pybo.demos.intermediate.main()
# Out:
# CPU times: user 39.1 s, sys: 1 s, total: 40.1 s
# Wall time: 40.1 s

# %%
# %%time
# %matplotlib inline
pybo.demos.advanced.main()
# Out:
# CPU times: user 31.6 s, sys: 530 ms, total: 32.2 s
# Wall time: 32.9 s
